# %% [markdown]
# # Lesion classification

# %%
import sys 
import os
sys.path.append(os.path.abspath("/net/people/plgamyshenin/masters-thesis---melanoma-analysis-with-fnn/experiment--2"))

# %%
import numpy as np
import tensorflow as tf
import tensorflow_addons as tfa
import matplotlib.pyplot as plt
from IPython.display import Image, display

from libs.isic import load
from libs.auc import calculate_auc
from libs.gradcam import display_gradcam, make_gradcam_heatmap, get_img_array

# %%
tf.get_logger().setLevel('ERROR')

# %% [markdown]
# ## Hyperparameter definition

# %%
strategy = tf.distribute.MirroredStrategy()

# %%
with strategy.scope():
    EPOCHS = 200
    SAMPLE_NUMBER = None
    
    TARGET_WIDTH, TARGET_HEIGHT = 299, 299
    O_MODEL = tf.keras.applications.vgg19.VGG19(
        include_top=False,
        weights='imagenet',
        input_shape=(TARGET_WIDTH, TARGET_HEIGHT, 3),
        pooling='avg'
    )
    RETRAINABLE_LAYERS = ['block5_conv3', 'block5_conv4']
    LAST_LAYER = 'block5_conv4'
    PREPROCESSING = tf.keras.applications.vgg19.preprocess_input

# %% [markdown]
# ## Load the ISIC Archive dataset

# %%
(training_set, validation_set, testing_set), class_weights, class_number = load(SAMPLE_NUMBER)
# Out:
# /net/people/plgamyshenin/masters-thesis---melanoma-analysis-with-fnn/experiment--2/libs/isic/load.py:8: DtypeWarning: Columns (3,11,12,14,15,17,18,19) have mixed types. Specify dtype option on import or set low_memory=False.
#   metadata = pd.read_csv(f"{os.environ['SCRATCH']}/isic-archive/metadata.csv")
# Found 30286 validated image filenames belonging to 10 classes.
# Found 7571 validated image filenames belonging to 10 classes.
# Found 4207 validated image filenames belonging to 10 classes.

# %% [markdown]
# ## Model definition

# %%
class LesionClassifier(tf.keras.Model):
    def __init__(self):
        super(LesionClassifier, self).__init__()
        
        self.rescale = tf.keras.layers.Rescaling(scale=1. / 255)
        
        self.o_model = O_MODEL
        for layer in self.o_model.layers:
            if layer.name in RETRAINABLE_LAYERS:
                layer.trainable = True
        else:
            layer.trainable = False
        
        self.dense = tf.keras.layers.Dense(class_number, activation='softmax')
        
    def call(self, inputs):
        o_outputs = self.rescale(inputs)
        o_outputs = self.o_model(o_outputs)

        outputs = self.dense(o_outputs)

        return outputs

# %%
checkpoint_path = 'checkpoint'

checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    checkpoint_path,
    monitor='val_loss',
    save_best_only=True,
    save_weights_only=False,
    save_freq='epoch',
    mode='auto'
)

# %%
early_stop_callback = tf.keras.callbacks.EarlyStopping(
    monitor="val_loss", 
    min_delta=0.01, 
    patience=15, 
    restore_best_weights=True
)

# %%
time_stopping = tfa.callbacks.TimeStopping(seconds=65 * 3600)

# %% [markdown]
# ## Training

# %%
with strategy.scope():
    model = LesionClassifier()
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
model.fit(
    training_set, 
    validation_data=validation_set, 
    epochs=EPOCHS,
    callbacks=[
        checkpoint_callback,
        early_stop_callback,
        time_stopping
    ]
)
# Out:
# Epoch 1/200
# 947/947 [==============================] - ETA: 0s - loss: 1.6669 - accuracy: 0.6653
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 16). These functions will not be directly callable after loading.
# 947/947 [==============================] - 2393s 3s/step - loss: 1.6669 - accuracy: 0.6653 - val_loss: 1.2384 - val_accuracy: 0.6588
# Epoch 2/200
# 947/947 [==============================] - ETA: 0s - loss: 1.2057 - accuracy: 0.6661
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 16). These functions will not be directly callable after loading.
# 947/947 [==============================] - 2366s 2s/step - loss: 1.2057 - accuracy: 0.6661 - val_loss: 1.2224 - val_accuracy: 0.6588
# Epoch 3/200
# 947/947 [==============================] - ETA: 0s - loss: 1.1999 - accuracy: 0.6670
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 16). These functions will not be directly callable after loading.
# 947/947 [==============================] - 2356s 2s/step - loss: 1.1999 - accuracy: 0.6670 - val_loss: 1.2203 - val_accuracy: 0.6588
# Epoch 4/200
# 947/947 [==============================] - 2405s 3s/step - loss: 1.1998 - accuracy: 0.6670 - val_loss: 1.2208 - val_accuracy: 0.6588
# Epoch 5/200
# 947/947 [==============================] - 2336s 2s/step - loss: 1.2003 - accuracy: 0.6670 - val_loss: 1.2207 - val_accuracy: 0.6588
# Epoch 6/200
# 947/947 [==============================] - 2335s 2s/step - loss: 1.2002 - accuracy: 0.6670 - val_loss: 1.2204 - val_accuracy: 0.6588
# Epoch 7/200
# 947/947 [==============================] - ETA: 0s - loss: 1.1993 - accuracy: 0.6670
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 16). These functions will not be directly callable after loading.
# 947/947 [==============================] - 2339s 2s/step - loss: 1.1993 - accuracy: 0.6670 - val_loss: 1.2187 - val_accuracy: 0.6588
# Epoch 8/200
# 947/947 [==============================] - 2341s 2s/step - loss: 1.1993 - accuracy: 0.6670 - val_loss: 1.2198 - val_accuracy: 0.6588
# Epoch 9/200
# 947/947 [==============================] - 2337s 2s/step - loss: 1.1996 - accuracy: 0.6670 - val_loss: 1.2228 - val_accuracy: 0.6588
# Epoch 10/200
# 947/947 [==============================] - 2340s 2s/step - loss: 1.1993 - accuracy: 0.6670 - val_loss: 1.2192 - val_accuracy: 0.6588
# Epoch 11/200
# 947/947 [==============================] - 2335s 2s/step - loss: 1.1990 - accuracy: 0.6670 - val_loss: 1.2395 - val_accuracy: 0.6588
# Epoch 12/200
# 947/947 [==============================] - 2343s 2s/step - loss: 1.1995 - accuracy: 0.6670 - val_loss: 1.2188 - val_accuracy: 0.6588
# Epoch 13/200
# 947/947 [==============================] - 2338s 2s/step - loss: 1.1990 - accuracy: 0.6670 - val_loss: 1.2187 - val_accuracy: 0.6588
# Epoch 14/200
# 947/947 [==============================] - 2341s 2s/step - loss: 1.1991 - accuracy: 0.6670 - val_loss: 1.2190 - val_accuracy: 0.6588
# Epoch 15/200
# 947/947 [==============================] - 2337s 2s/step - loss: 1.1990 - accuracy: 0.6670 - val_loss: 1.2217 - val_accuracy: 0.6588
# Epoch 16/200
# 947/947 [==============================] - 2333s 2s/step - loss: 1.1987 - accuracy: 0.6670 - val_loss: 1.2217 - val_accuracy: 0.6588
# Epoch 17/200
# 947/947 [==============================] - 2340s 2s/step - loss: 1.1986 - accuracy: 0.6670 - val_loss: 1.2206 - val_accuracy: 0.6588

# %% [markdown]
# ## Testing

# %%
model.load_weights(checkpoint_path)

# %%
groundtruth_labels = np.concatenate([testing_set[i][1] for i in range(len(testing_set))], axis=0)

# %%
predicted_labels = model.predict(testing_set)
# Out:
# 132/132 [==============================] - 258s 2s/step

# %%
fpr, tpr, auc_metric = calculate_auc(testing_set, groundtruth_labels, predicted_labels)

# %%
auc_metric
# Out:
# {'actinic keratosis': 0.5,
#  'basal cell carcinoma': 0.5,
#  'dermatofibroma': 0.5,
#  'melanoma': 0.5,
#  'nevus': 0.5,
#  'pigmented benign keratosis': 0.5,
#  'seborrheic keratosis': 0.5,
#  'solar lentigo': 0.5,
#  'squamous cell carcinoma': 0.5,
#  'vascular lesion': 0.5}

# %%
# %matplotlib inline 

plt.rcParams['axes.titley'] = -0.3

for diagnosis in testing_set.class_indices:
    plt.plot(fpr[diagnosis], tpr[diagnosis], label=diagnosis)
    
plt.plot([0, 1], [0, 1], 'k--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(bbox_to_anchor=(1.6, 1), loc="upper right")
plt.show()

# %% [markdown]
# ## GradCam

# %%
melanoma_im_path = f"{os.environ['SCRATCH']}/isic-archive/ISIC_0000031.jpg"

# %%
display(Image(melanoma_im_path, width=600))

# %%
img_array = PREPROCESSING(get_img_array(melanoma_im_path, size=(299, 299)))

# %%
heatmap = make_gradcam_heatmap(img_array, model.o_model, LAST_LAYER)

# %%
display_gradcam(melanoma_im_path, heatmap)
# Out:
# <PIL.Image.Image image mode=RGB size=600x450 at 0x2B9D17F97EE0>
