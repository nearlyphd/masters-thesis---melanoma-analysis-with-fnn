# %% [markdown]
# # Lesion classification

# %%
import sys 
import os
sys.path.append(os.path.abspath("/net/people/plgamyshenin/masters-thesis---melanoma-analysis-with-fnn/experiment--2"))

# %%
import numpy as np
import tensorflow as tf
import tensorflow_addons as tfa
import matplotlib.pyplot as plt
from IPython.display import Image, display

from libs.isic import load
from libs.fractal_percolation_module import FractalModule
from libs.auc import calculate_auc
from libs.gradcam import display_gradcam, make_gradcam_heatmap, get_img_array

# %%
tf.get_logger().setLevel('ERROR')

# %% [markdown]
# ## Hyperparameter definition

# %%
strategy = tf.distribute.MirroredStrategy()

# %%
with strategy.scope():
    EPOCHS = 200
    SAMPLE_NUMBER = None
    
    TARGET_WIDTH, TARGET_HEIGHT = 299, 299
    FRACTAL_WIDTH, FRACTAL_HEIGHT = 10, 10
    FRACTAL_MODULE = FractalModule(FRACTAL_WIDTH, FRACTAL_HEIGHT)
    O_MODEL = tf.keras.applications.vgg19.VGG19(
        include_top=False,
        weights='imagenet',
        input_shape=(TARGET_WIDTH, TARGET_HEIGHT, 3),
        pooling='avg'
    )
    F_MODEL = tf.keras.applications.vgg19.VGG19(
        include_top=False,
        weights='imagenet',
        input_shape=(TARGET_WIDTH, TARGET_HEIGHT, 3),
        pooling='avg'
    )
    RETRAINABLE_LAYERS = []
    LAST_LAYER = 'block5_conv4'
    PREPROCESSING = tf.keras.applications.vgg19.preprocess_input

# %% [markdown]
# ## Load the ISIC Archive dataset

# %%
(training_set, validation_set, testing_set), class_weights, class_number = load(SAMPLE_NUMBER)
# Out:
# /net/people/plgamyshenin/masters-thesis---melanoma-analysis-with-fnn/experiment--2/libs/isic/load.py:8: DtypeWarning: Columns (3,11,12,14,15,17,18,19) have mixed types. Specify dtype option on import or set low_memory=False.
#   metadata = pd.read_csv(f"{os.environ['SCRATCH']}/isic-archive/metadata.csv")
# Found 30286 validated image filenames belonging to 10 classes.
# Found 7571 validated image filenames belonging to 10 classes.
# Found 4207 validated image filenames belonging to 10 classes.

# %% [markdown]
# ## Model definition

# %%
class LesionClassifier(tf.keras.Model):
    def __init__(self):
        super(LesionClassifier, self).__init__()
        
        self.fractal_module = FRACTAL_MODULE
        
        self.resize = tf.keras.layers.Resizing(
            width=TARGET_WIDTH,
            height=TARGET_HEIGHT
        )
        
        self.rescale = tf.keras.layers.Rescaling(scale=1. / 255)
        
        self.o_model = O_MODEL
        for layer in self.o_model.layers:
            if layer.name in RETRAINABLE_LAYERS:
                layer.trainable = True
        else:
            layer.trainable = False
            
        self.f_model = F_MODEL
        for layer in self.f_model.layers:
            if layer.name in RETRAINABLE_LAYERS:
                layer.trainable = True
        else:
            layer.trainable = False
            
        self.fusion = tf.keras.layers.Concatenate()
        
        self.dense = tf.keras.layers.Dense(class_number, activation='softmax')
        
    def call(self, inputs):
        f_outputs = self.fractal_module(inputs)
        f_outputs = self.resize(f_outputs)
        f_outputs = self.rescale(f_outputs)
        f_outputs = self.f_model(f_outputs)

        o_outputs = self.rescale(inputs)
        o_outputs = self.o_model(o_outputs)

        outputs = self.fusion([f_outputs, o_outputs])
        outputs = self.dense(outputs)

        return outputs

# %%
checkpoint_path = 'checkpoint'

checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    checkpoint_path,
    monitor='val_loss',
    save_best_only=True,
    save_weights_only=False,
    save_freq='epoch',
    mode='auto'
)

# %%
early_stop_callback = tf.keras.callbacks.EarlyStopping(
    monitor="val_loss", 
    min_delta=0.01, 
    patience=15, 
    restore_best_weights=True
)

# %%
time_stopping = tfa.callbacks.TimeStopping(seconds=65 * 3600)

# %% [markdown]
# ## Training

# %%
with strategy.scope():
    model = LesionClassifier()
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
model.fit(
    training_set, 
    validation_data=validation_set, 
    epochs=EPOCHS,
    callbacks=[
        checkpoint_callback,
        early_stop_callback,
        time_stopping
    ]
)
# Out:
# Epoch 1/200
# 947/947 [==============================] - ETA: 0s - loss: 5.7905 - accuracy: 0.6630
# WARNING:absl:Found untraced functions such as feature_channel_layer_call_fn, feature_channel_layer_call_and_return_conditional_losses, feature_channel_1_layer_call_fn, feature_channel_1_layer_call_and_return_conditional_losses, feature_channel_2_layer_call_fn while saving (showing 5 of 134). These functions will not be directly callable after loading.
# 947/947 [==============================] - 4460s 5s/step - loss: 5.7905 - accuracy: 0.6630 - val_loss: 1.1853 - val_accuracy: 0.6701
# Epoch 2/200
# 947/947 [==============================] - 4073s 4s/step - loss: 1.2035 - accuracy: 0.6654 - val_loss: 1.1994 - val_accuracy: 0.6701
# Epoch 3/200
# 947/947 [==============================] - 4072s 4s/step - loss: 1.2083 - accuracy: 0.6663 - val_loss: 1.1981 - val_accuracy: 0.6701
# Epoch 4/200
# 947/947 [==============================] - 4069s 4s/step - loss: 1.2166 - accuracy: 0.6660 - val_loss: 1.1959 - val_accuracy: 0.6701
# Epoch 5/200
# 947/947 [==============================] - 4068s 4s/step - loss: 1.2029 - accuracy: 0.6663 - val_loss: 1.1964 - val_accuracy: 0.6701
# Epoch 6/200
# 947/947 [==============================] - 4069s 4s/step - loss: 1.2022 - accuracy: 0.6663 - val_loss: 1.1952 - val_accuracy: 0.6701
# Epoch 7/200
# 947/947 [==============================] - 4070s 4s/step - loss: 1.2019 - accuracy: 0.6663 - val_loss: 1.1969 - val_accuracy: 0.6701
# Epoch 8/200
# 947/947 [==============================] - 4069s 4s/step - loss: 1.2030 - accuracy: 0.6663 - val_loss: 1.2006 - val_accuracy: 0.6701
# Epoch 9/200
# 947/947 [==============================] - 4071s 4s/step - loss: 1.2018 - accuracy: 0.6663 - val_loss: 1.1987 - val_accuracy: 0.6701
# Epoch 10/200
# 947/947 [==============================] - 4069s 4s/step - loss: 1.2016 - accuracy: 0.6663 - val_loss: 1.1947 - val_accuracy: 0.6701
# Epoch 11/200
# 947/947 [==============================] - 4071s 4s/step - loss: 1.2012 - accuracy: 0.6663 - val_loss: 1.1953 - val_accuracy: 0.6701
# Epoch 12/200
# 947/947 [==============================] - 4071s 4s/step - loss: 1.2009 - accuracy: 0.6663 - val_loss: 1.1994 - val_accuracy: 0.6701
# Epoch 13/200
# 947/947 [==============================] - 4073s 4s/step - loss: 1.2086 - accuracy: 0.6658 - val_loss: 1.1933 - val_accuracy: 0.6701
# Epoch 14/200
# 947/947 [==============================] - 4072s 4s/step - loss: 1.2004 - accuracy: 0.6663 - val_loss: 1.1943 - val_accuracy: 0.6701
# Epoch 15/200
# 947/947 [==============================] - 4070s 4s/step - loss: 1.2005 - accuracy: 0.6663 - val_loss: 1.1973 - val_accuracy: 0.6701
# Epoch 16/200
# 947/947 [==============================] - 4072s 4s/step - loss: 1.2002 - accuracy: 0.6663 - val_loss: 1.1967 - val_accuracy: 0.6701

# %% [markdown]
# ## Testing

# %%
model.load_weights(checkpoint_path)

# %%
groundtruth_labels = np.concatenate([testing_set[i][1] for i in range(len(testing_set))], axis=0)

# %%
predicted_labels = model.predict(testing_set)
# Out:
# 132/132 [==============================] - 438s 3s/step

# %%
fpr, tpr, auc_metric = calculate_auc(testing_set, groundtruth_labels, predicted_labels)

# %%
auc_metric
# Out:
# {'actinic keratosis': 0.5671641791044776,
#  'basal cell carcinoma': 0.5240900030810053,
#  'dermatofibroma': 0.41334741915782175,
#  'melanoma': 0.664527666882016,
#  'nevus': 0.6305037115884746,
#  'pigmented benign keratosis': 0.5964102442166608,
#  'seborrheic keratosis': 0.5452002580688976,
#  'solar lentigo': 0.558869422815474,
#  'squamous cell carcinoma': 0.531202682240969,
#  'vascular lesion': 0.5758167761243661}

# %%
# %matplotlib inline 

plt.rcParams['axes.titley'] = -0.3

for diagnosis in testing_set.class_indices:
    plt.plot(fpr[diagnosis], tpr[diagnosis], label=diagnosis)
    
plt.plot([0, 1], [0, 1], 'k--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(bbox_to_anchor=(1.6, 1), loc="upper right")
plt.show()

# %% [markdown]
# ## GradCam

# %%
melanoma_im_path = f"{os.environ['SCRATCH']}/isic-archive/ISIC_0000031.jpg"

# %%
display(Image(melanoma_im_path, width=600))

# %%
img_array = PREPROCESSING(get_img_array(melanoma_im_path, size=(299, 299)))

# %%
heatmap = make_gradcam_heatmap(img_array, model.o_model, LAST_LAYER)

# %%
display_gradcam(melanoma_im_path, heatmap)
# Out:
# <PIL.Image.Image image mode=RGB size=600x450 at 0x2AE26031AB20>
