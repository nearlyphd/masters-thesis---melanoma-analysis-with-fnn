# %% [markdown]
# # Lesion classification

# %%
import sys 
import os
sys.path.append(os.path.abspath("/net/people/plgamyshenin/masters-thesis---melanoma-analysis-with-fnn/experiment--2"))

# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from IPython.display import Image, display

from libs.isic import load
from libs.fractal_percolation_module import FractalModule
from libs.auc import calculate_auc
from libs.gradcam import display_gradcam, make_gradcam_heatmap, get_img_array

# %%
tf.get_logger().setLevel('ERROR')

# %% [markdown]
# ## Hyperparameter definition

# %%
strategy = tf.distribute.MirroredStrategy()

# %%
with strategy.scope():
    TARGET_WIDTH, TARGET_HEIGHT = 299, 299
    FRACTAL_WIDTH, FRACTAL_HEIGHT = 10, 10
    FRACTAL_MODULE = FractalModule(FRACTAL_WIDTH, FRACTAL_HEIGHT)
    O_MODEL = tf.keras.applications.inception_resnet_v2.InceptionResNetV2(
        include_top=False,
        weights='imagenet',
        input_shape=(TARGET_WIDTH, TARGET_HEIGHT, 3),
        pooling='avg'
    )
    F_MODEL = tf.keras.applications.inception_resnet_v2.InceptionResNetV2(
        include_top=False,
        weights='imagenet',
        input_shape=(TARGET_WIDTH, TARGET_HEIGHT, 3),
        pooling='avg'
    )
    RETRAINABLE_LAYERS = ['conv_7b']
    PREPROCESSING = tf.keras.applications.inception_resnet_v2.preprocess_input

# %% [markdown]
# ## Load the ISIC Archive dataset

# %%
(training_set, validation_set, testing_set), class_weights, class_number = load()
# Out:
# /net/people/plgamyshenin/masters-thesis---melanoma-analysis-with-fnn/experiment--2/libs/isic/load.py:8: DtypeWarning: Columns (3,11,12,14,15,17,18,19) have mixed types. Specify dtype option on import or set low_memory=False.
#   metadata = pd.read_csv(f"{os.environ['SCRATCH']}/isic-archive/metadata.csv")
# Found 30286 validated image filenames belonging to 10 classes.
# Found 7571 validated image filenames belonging to 10 classes.
# Found 4207 validated image filenames belonging to 10 classes.

# %% [markdown]
# ## Model definition

# %%
class LesionClassifier(tf.keras.Model):
    def __init__(self):
        super(LesionClassifier, self).__init__()
        
        self.fractal_module = FRACTAL_MODULE
        
        self.resize = tf.keras.layers.Resizing(
            width=TARGET_WIDTH,
            height=TARGET_HEIGHT
        )
        
        self.rescale = tf.keras.layers.Rescaling(scale=1. / 255)
        
        self.o_model = O_MODEL
        for layer in self.o_model.layers:
            if layer.name in RETRAINABLE_LAYERS:
                layer.trainable = True
        else:
            layer.trainable = False
            
        self.f_model = F_MODEL
        for layer in self.f_model.layers:
            if layer.name in RETRAINABLE_LAYERS:
                layer.trainable = True
        else:
            layer.trainable = False
            
        self.fusion = tf.keras.layers.Concatenate()
        
        self.dense = tf.keras.layers.Dense(class_number, activation='softmax')
        
    def call(self, inputs):
        f_outputs = self.fractal_module(inputs)
        f_outputs = self.resize(f_outputs)
        f_outputs = self.rescale(f_outputs)
        f_outputs = self.f_model(f_outputs)

        o_outputs = self.rescale(inputs)
        o_outputs = self.o_model(o_outputs)

        outputs = self.fusion([f_outputs, o_outputs])
        outputs = self.dense(outputs)

        return outputs

# %%
checkpoint_path = 'checkpoints/model.ckpt'

checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    checkpoint_path,
    monitor='val_loss',
    verbose=1,
    save_best_only=True,
    save_weights_only=False,
    save_freq='epoch',
    mode='auto'
)

# %%
early_stop_callback = tf.keras.callbacks.EarlyStopping(
    monitor="val_loss", 
    min_delta=0.01, 
    patience=5, 
    restore_best_weights=True
)

# %% [markdown]
# ## Training

# %%
with strategy.scope():
    model = LesionClassifier()
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
model.fit(
    training_set, 
    validation_data=validation_set, 
    epochs=30,
    callbacks=[
        early_stop_callback
    ]
)
# Out:
# Epoch 1/30
# 947/947 [==============================] - 5718s 6s/step - loss: 0.8225 - accuracy: 0.7238 - val_loss: 2.8260 - val_accuracy: 0.5744
# Epoch 2/30
# 947/947 [==============================] - 5383s 6s/step - loss: 0.7315 - accuracy: 0.7522 - val_loss: 0.7455 - val_accuracy: 0.7323
# Epoch 3/30
# 947/947 [==============================] - 5228s 6s/step - loss: 0.6645 - accuracy: 0.7708 - val_loss: 7.0130 - val_accuracy: 0.5740
# Epoch 4/30
# 947/947 [==============================] - 5031s 5s/step - loss: 0.6331 - accuracy: 0.7798 - val_loss: 0.9510 - val_accuracy: 0.7165
# Epoch 5/30
# 947/947 [==============================] - 5036s 5s/step - loss: 0.5983 - accuracy: 0.7892 - val_loss: 0.5947 - val_accuracy: 0.7883
# Epoch 6/30
# 947/947 [==============================] - 5089s 5s/step - loss: 0.5915 - accuracy: 0.7947 - val_loss: 0.8748 - val_accuracy: 0.7229
# Epoch 7/30
# 947/947 [==============================] - 5020s 5s/step - loss: 0.5657 - accuracy: 0.8033 - val_loss: 0.5607 - val_accuracy: 0.8045
# Epoch 8/30
# 947/947 [==============================] - 4988s 5s/step - loss: 0.6059 - accuracy: 0.7900 - val_loss: 0.8418 - val_accuracy: 0.7307
# Epoch 9/30
# 947/947 [==============================] - 4965s 5s/step - loss: 0.5488 - accuracy: 0.8086 - val_loss: 0.6040 - val_accuracy: 0.7936
# Epoch 10/30
# 947/947 [==============================] - 4974s 5s/step - loss: 0.5217 - accuracy: 0.8128 - val_loss: 0.5264 - val_accuracy: 0.8094
# Epoch 11/30
# 947/947 [==============================] - 5020s 5s/step - loss: 0.5042 - accuracy: 0.8209 - val_loss: 0.5567 - val_accuracy: 0.8062
# Epoch 12/30
# 947/947 [==============================] - 5048s 5s/step - loss: 0.5159 - accuracy: 0.8183 - val_loss: 0.5154 - val_accuracy: 0.8123
# Epoch 13/30
# 947/947 [==============================] - 4988s 5s/step - loss: 0.5077 - accuracy: 0.8205 - val_loss: 0.5313 - val_accuracy: 0.8111
# Epoch 14/30
# 947/947 [==============================] - 4963s 5s/step - loss: 0.4801 - accuracy: 0.8299 - val_loss: 0.5242 - val_accuracy: 0.8153
# Epoch 15/30
# 947/947 [==============================] - 4991s 5s/step - loss: 0.4615 - accuracy: 0.8375 - val_loss: 0.5437 - val_accuracy: 0.8044
# Epoch 16/30
# 947/947 [==============================] - 5002s 5s/step - loss: 0.4444 - accuracy: 0.8404 - val_loss: 0.5044 - val_accuracy: 0.8167
# Epoch 17/30
# 947/947 [==============================] - 4988s 5s/step - loss: 0.4245 - accuracy: 0.8468 - val_loss: 0.5142 - val_accuracy: 0.8227
# Epoch 18/30
# 947/947 [==============================] - 5058s 5s/step - loss: 0.4236 - accuracy: 0.8449 - val_loss: 4.9528 - val_accuracy: 0.7545
# Epoch 19/30
# 947/947 [==============================] - 5230s 6s/step - loss: 0.4215 - accuracy: 0.8482 - val_loss: 0.4930 - val_accuracy: 0.8198
# Epoch 20/30
# 947/947 [==============================] - 5361s 6s/step - loss: 0.3919 - accuracy: 0.8599 - val_loss: 0.5409 - val_accuracy: 0.8099
# Epoch 21/30
# 947/947 [==============================] - 4954s 5s/step - loss: 0.4117 - accuracy: 0.8535 - val_loss: 0.4789 - val_accuracy: 0.8325
# Epoch 22/30
# 947/947 [==============================] - 4920s 5s/step - loss: 0.3746 - accuracy: 0.8639 - val_loss: 0.4934 - val_accuracy: 0.8317
# Epoch 23/30
# 947/947 [==============================] - 4927s 5s/step - loss: 0.3592 - accuracy: 0.8694 - val_loss: 0.4842 - val_accuracy: 0.8312
# Epoch 24/30
# 947/947 [==============================] - 4930s 5s/step - loss: 0.3506 - accuracy: 0.8708 - val_loss: 0.4946 - val_accuracy: 0.8247
# Epoch 25/30
# 947/947 [==============================] - 4933s 5s/step - loss: 0.3425 - accuracy: 0.8745 - val_loss: 0.4761 - val_accuracy: 0.8315
# Epoch 26/30
# 947/947 [==============================] - 4934s 5s/step - loss: 0.3408 - accuracy: 0.8769 - val_loss: 1.5695 - val_accuracy: 0.7815

# %% [markdown]
# ## Testing

# %%
groundtruth_labels = np.concatenate([testing_set[i][1] for i in range(len(testing_set))], axis=0)

# %%
predicted_labels = model.predict(testing_set)
# Out:
# 132/132 [==============================] - 469s 3s/step

# %%
fpr, tpr, auc_metric = calculate_auc(testing_set, groundtruth_labels, predicted_labels)

# %%
auc_metric
# Out:
# {'actinic keratosis': 0.9748367691291908,
#  'basal cell carcinoma': 0.9837796067632384,
#  'dermatofibroma': 0.9905180840664711,
#  'melanoma': 0.9413906733518744,
#  'nevus': 0.9688869617304628,
#  'pigmented benign keratosis': 0.9828056863771149,
#  'seborrheic keratosis': 0.9568013187599801,
#  'solar lentigo': 0.9610341533317411,
#  'squamous cell carcinoma': 0.972944291508185,
#  'vascular lesion': 0.9999633175598841}

# %%
# %matplotlib inline 

plt.rcParams['axes.titley'] = -0.3

for diagnosis in testing_set.class_indices:
    plt.plot(fpr[diagnosis], tpr[diagnosis], label=diagnosis)
    
plt.plot([0, 1], [0, 1], 'k--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(bbox_to_anchor=(1.6, 1), loc="upper right")
plt.show()

# %% [markdown]
# ## GradCam

# %%
melanoma_im_path = f"{os.environ['SCRATCH']}/isic-archive/ISIC_0000031.jpg"

# %%
display(Image(melanoma_im_path, width=600))

# %%
img_array = PREPROCESSING(get_img_array(melanoma_im_path, size=(299, 299)))

# %%
heatmap = make_gradcam_heatmap(img_array, model.o_model, RETRAINABLE_LAYERS[-1])

# %%
display_gradcam(melanoma_im_path, heatmap)
# Out:
# <PIL.Image.Image image mode=RGB size=600x450 at 0x2B9F06448B50>
